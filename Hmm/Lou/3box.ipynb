# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from hmmlearn import hmm, vhmm
import joblib, pickle
import seaborn as sns
import networkx as nx
import pprint as pprint

# %% [markdown]
# # Import data

# %%
X_head = pd.pandas.read_csv("E:/UQAM/Recherche/Thomas/data/head_coords.csv",  names=['Gauche_head', 'Haut_head', 'Largeur_head', 'Longeur_head'])
X_snout = pd.pandas.read_csv("E:/UQAM/Recherche/Thomas/data/snout_coords.csv",  names=['Gauche_snout', 'Haut_snout', 'Largeur_snout', 'Longeur_snout'])
X_cow = pd.pandas.read_csv("E:/UQAM/Recherche/Thomas/data/cow_coords.csv",  names=['Gauche_cow', 'Haut_cow', 'Largeur_cow', 'Longeur_cow'])
X_cow = pd.DataFrame(X_cow)
# pprint.pp(X_cow)

X = np.concatenate([X_head, X_snout, X_cow], axis=1)
df = pd.DataFrame(X)

lengths = [len(X_head), len(X_snout), len(X_cow)]

lengths
len(X)
X.shape
df
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.171130  0.391502  0.516889  0.663207  0.182095  0.564310  0.168614
# 1     0.172891  0.411942  0.520052  0.637912  0.183028  0.535635  0.172195
# 2     0.174267  0.428778  0.522600  0.617213  0.183667  0.513194  0.175082
# 3     0.175295  0.442282  0.524578  0.600754  0.184043  0.496454  0.177336
# 4     0.176014  0.452724  0.526035  0.588182  0.184191  0.484884  0.179015
# ...        ...       ...       ...       ...       ...       ...       ...
# 1370  0.223776  0.727776  0.387667  0.667878  0.225228  0.723106  0.152929
# 1371  0.218780  0.710023  0.390090  0.669977  0.224485  0.714644  0.142189
# 1372  0.216704  0.692295  0.391427  0.670888  0.227563  0.707101  0.129164
# 1373  0.217767  0.674704  0.391580  0.670472  0.234720  0.700602  0.113701
# 1374  0.222187  0.657364  0.390451  0.668593  0.246215  0.695273  0.095645
#
#             7         8         9         10        11
# 0     0.233524  0.166457  0.008873  1.001398  1.048313
# 1     0.265240  0.168241  0.015035  0.992619  1.041969
# 2     0.289693  0.169740  0.020408  0.984892  1.036530
# 3     0.307510  0.170978  0.025045  0.978149  1.031934
# 4     0.319314  0.171978  0.028997  0.972324  1.028118
# ...        ...       ...       ...       ...       ...
# 1370  0.182148  0.236992  0.083251  0.545055  1.410483
# 1371  0.174504  0.220609  0.078841  0.564080  1.413386
# 1372  0.165155  0.202257  0.074052  0.587869  1.416906
# 1373  0.153982  0.181830  0.068883  0.616711  1.421086
# 1374  0.140863  0.159226  0.063333  0.650898  1.425968
#
# [1375 rows x 12 columns]

# %% [markdown]
# # Train model

# %%
em_scores = list()
vi_scores = list()
em_models = list()
vi_models = list()
for n_components in range(2, 10):
    for idx in range(50):
        # iter = 5 
        em_model = hmm.GaussianHMM(n_components=n_components, random_state=idx,covariance_type = "full", n_iter=52)
        # variational inference
        vi_model = vhmm.VariationalGaussianHMM(n_components=n_components, random_state=idx, covariance_type='full', n_iter=52)
        em_model.fit(X)
        vi_model.fit(X)
        em_models.append(em_model)
        vi_models.append(vi_model)
        em_scores.append(em_model.score(X))
        vi_scores.append(vi_model.score(X))
        # ll = em_model.monitor_.history[-1]
        """ print(f"Training EM({n_components}) Final Log Likelihood={ll} "
              f"Iterations={len(vi_model.monitor_.history)} ") """
        # print(f'Converged: {em_model.monitor_.converged}\t\t'f'Score: {scores[-1]}')

# get the best model
em_model = em_models[np.argmax(em_scores)]
vi_model = vi_models[np.argmax(vi_scores)]
# print(f'The best model had a score of {max(scores)} and 'f'{em_model.n_components} components')


em_Z = em_model.predict(X)
vi_Z = vi_model.predict(X)

    
joblib.dump(em_model, '../../models/EM/hmm_model_3box_Lou.pkl')
joblib.dump(vi_model, '../../models/Vi/hmm_model_3box_Lou.pkl')
# Out:
# Model is not converging.  Current: 34213.52856639877 is not greater than 34213.52927291625. Delta is -0.0007065174795570783
# Model is not converging.  Current: 34213.52856392818 is not greater than 34213.52927517424. Delta is -0.0007112460589269176
# Model is not converging.  Current: 34213.52860398992 is not greater than 34213.52929464272. Delta is -0.0006906527996761724
# Model is not converging.  Current: 34213.52856582091 is not greater than 34213.529273455. Delta is -0.0007076340916682966
# Model is not converging.  Current: 34213.52856596989 is not greater than 34213.529273315275. Delta is -0.0007073453816701658
# Model is not converging.  Current: 34213.52856503082 is not greater than 34213.52927417977. Delta is -0.0007091489460435696
# Model is not converging.  Current: 34213.528563521104 is not greater than 34213.52927553724. Delta is -0.0007120161390048452
# Model is not converging.  Current: 34213.52857077542 is not greater than 34213.52926866897. Delta is -0.0006978935489314608
# Model is not converging.  Current: 34213.528567056936 is not greater than 34213.52927229759. Delta is -0.0007052406508591957
# Model is not converging.  Current: 34213.52857346023 is not greater than 34213.529265912155. Delta is -0.0006924519257154316
# Model is not converging.  Current: 34213.5285631714 is not greater than 34213.52927584555. Delta is -0.0007126741475076415
# Model is not converging.  Current: 34213.52857885141 is not greater than 34213.52926004421. Delta is -0.0006811928033130243
# Model is not converging.  Current: 34213.54849693075 is not greater than 34213.57671075529. Delta is -0.028213824538397603
# Model is not converging.  Current: 34213.52856793755 is not greater than 34213.529271459105. Delta is -0.000703521553077735
# Model is not converging.  Current: 34213.5285539327 is not greater than 34213.52928264478. Delta is -0.0007287120752152987
# Model is not converging.  Current: 34213.52856552394 is not greater than 34213.52927372756. Delta is -0.0007082036172505468
# Model is not converging.  Current: 34213.528531495256 is not greater than 34213.52928758631. Delta is -0.0007560910526080988
# Model is not converging.  Current: 34213.52856873825 is not greater than 34213.529270684216. Delta is -0.0007019459662842564
# Model is not converging.  Current: 34213.52856364364 is not greater than 34213.52927575798. Delta is -0.0007121143426047638
# Model is not converging.  Current: 34213.52856753695 is not greater than 34213.529271841195. Delta is -0.000704304242390208
# Model is not converging.  Current: 34210.46508434453 is not greater than 34210.525576200176. Delta is -0.06049185564916115
# Model is not converging.  Current: 34213.52856811473 is not greater than 34213.52927128883. Delta is -0.0007031741042737849
# Model is not converging.  Current: 34213.528567933914 is not greater than 34213.52927146172. Delta is -0.0007035278031253256
# Model is not converging.  Current: 34213.52852730188 is not greater than 34213.52929268524. Delta is -0.0007653833599761128
# Model is not converging.  Current: 34213.52856927704 is not greater than 34213.52927015811. Delta is -0.0007008810716797598
# Model is not converging.  Current: 34213.52856821559 is not greater than 34213.52927119124. Delta is -0.000702975652529858
# Model is not converging.  Current: 34213.5284952177 is not greater than 34213.52925904847. Delta is -0.0007638307652086951
# Model is not converging.  Current: 34213.52856158129 is not greater than 34213.529277223104. Delta is -0.0007156418141676113
# Model is not converging.  Current: 34213.52856590571 is not greater than 34213.5292733756. Delta is -0.0007074698878568597
# Model is not converging.  Current: 34213.52856627786 is not greater than 34213.529273028325. Delta is -0.0007067504629958421
# Model is not converging.  Current: 37267.90088478697 is not greater than 37268.059930988115. Delta is -0.15904620114451973
# Model is not converging.  Current: 38826.71147277304 is not greater than 38826.73498017722. Delta is -0.02350740418478381
# Model is not converging.  Current: 38826.0096436642 is not greater than 38826.01103585627. Delta is -0.0013921920690336265
# Model is not converging.  Current: 38825.70011934277 is not greater than 38825.7048477576. Delta is -0.004728414831333794
# Model is not converging.  Current: 38826.628938079586 is not greater than 38826.66850297049. Delta is -0.039564890903420746
# Model is not converging.  Current: 38826.67242998085 is not greater than 38826.70528475568. Delta is -0.03285477482859278
# Model is not converging.  Current: 38826.71607598715 is not greater than 38826.73703405383. Delta is -0.020958066685125232
# Model is not converging.  Current: 38826.721316866984 is not greater than 38826.72963049897. Delta is -0.00831363198813051
# Model is not converging.  Current: 38825.76338781319 is not greater than 38825.796368811076. Delta is -0.03298099788662512
# Model is not converging.  Current: 38826.71770035285 is not greater than 38826.741531548636. Delta is -0.023831195787352044
# Model is not converging.  Current: 38826.72609305985 is not greater than 38826.81026538731. Delta is -0.08417232745705405
# Model is not converging.  Current: 38826.721366103586 is not greater than 38826.73689008626. Delta is -0.01552398267085664
# Model is not converging.  Current: 38826.72112255856 is not greater than 38826.739916370505. Delta is -0.018793811941577587
# Model is not converging.  Current: 38826.71441976856 is not greater than 38826.73527858577. Delta is -0.020858817209955305
# Model is not converging.  Current: 38826.71963678701 is not greater than 38826.73967055496. Delta is -0.020033767948916648
# Model is not converging.  Current: 38826.68442194793 is not greater than 38826.72931807077. Delta is -0.04489612283941824
# Model is not converging.  Current: 38826.13586022619 is not greater than 38826.373944212326. Delta is -0.2380839861361892
# Model is not converging.  Current: 38826.72021010007 is not greater than 38826.74088898951. Delta is -0.020678889435657766
# Model is not converging.  Current: 33347.893471217874 is not greater than 33348.13843304529. Delta is -0.2449618274185923
# Model is not converging.  Current: 38826.716609452655 is not greater than 38826.73710156969. Delta is -0.020492117037065327
# Model is not converging.  Current: 38826.7210293021 is not greater than 38826.737453946815. Delta is -0.016424644716607872
# Model is not converging.  Current: 38826.717935143046 is not greater than 38826.72584692609. Delta is -0.007911783046438359
# Model is not converging.  Current: 40763.97640823124 is not greater than 40763.98561877849. Delta is -0.009210547250404488
# Model is not converging.  Current: 36774.1729690356 is not greater than 36774.18693301023. Delta is -0.013963974626676645
# Model is not converging.  Current: 40444.183308611784 is not greater than 40444.187296029086. Delta is -0.003987417301686946
# Model is not converging.  Current: 40551.61373008967 is not greater than 40551.67397013367. Delta is -0.060240043996600434
# Model is not converging.  Current: 40513.02964133806 is not greater than 40513.08898389105. Delta is -0.0593425529950764
# Model is not converging.  Current: 36762.810026524545 is not greater than 36762.819427180206. Delta is -0.009400655661011115
# Model is not converging.  Current: 42910.96724730785 is not greater than 42910.98968995472. Delta is -0.022442646863055415
# Model is not converging.  Current: 41652.7821752073 is not greater than 41652.80851275559. Delta is -0.0263375482900301
# Model is not converging.  Current: 42546.33199752509 is not greater than 42546.34021729336. Delta is -0.008219768264098093
# Model is not converging.  Current: 38978.25209473846 is not greater than 38978.25874991067. Delta is -0.006655172204773407
# Model is not converging.  Current: 43295.237561102294 is not greater than 43295.23797233608. Delta is -0.0004112337846891023
# Model is not converging.  Current: 44763.90032269539 is not greater than 44763.90045590173. Delta is -0.00013320634025149047
# Model is not converging.  Current: 45028.06957225568 is not greater than 45028.07005645652. Delta is -0.00048420084203826264
# Model is not converging.  Current: 45250.82286480367 is not greater than 45250.827892498266. Delta is -0.005027694598538801
# Model is not converging.  Current: 40099.47106617624 is not greater than 40099.474323440314. Delta is -0.0032572640775470063
# Model is not converging.  Current: 45231.35195686933 is not greater than 45231.35800581237. Delta is -0.006048943039786536
# Model is not converging.  Current: 45485.47524118155 is not greater than 45485.4863637344. Delta is -0.011122552852611989
# Model is not converging.  Current: 45803.63582286365 is not greater than 45803.643641612325. Delta is -0.007818748672434594
# Model is not converging.  Current: 42494.59966884548 is not greater than 42494.602579366765. Delta is -0.0029105212815920822
# Model is not converging.  Current: 37540.96155872371 is not greater than 37540.98609531584. Delta is -0.024536592129152268
# Model is not converging.  Current: 41086.68464606039 is not greater than 41086.68625927978. Delta is -0.001613219385035336
# Model is not converging.  Current: 45422.54883263612 is not greater than 45422.55151797393. Delta is -0.002685337807633914
# Model is not converging.  Current: 47983.97161138161 is not greater than 47983.98194451817. Delta is -0.010333136560802814
# Model is not converging.  Current: 42126.717519007165 is not greater than 42126.72178867297. Delta is -0.004269665805622935
# Model is not converging.  Current: 46252.64312297876 is not greater than 46252.66282376427. Delta is -0.019700785509485286
# Model is not converging.  Current: 46457.0337309934 is not greater than 46457.04439562051. Delta is -0.01066462711605709
# Model is not converging.  Current: 46516.713307881 is not greater than 46516.715011009175. Delta is -0.0017031281749950722
# Model is not converging.  Current: 48780.75630755059 is not greater than 48780.78926031732. Delta is -0.03295276672724867
# Model is not converging.  Current: 48523.21514683239 is not greater than 48523.3402769923. Delta is -0.12513015991135035
# Model is not converging.  Current: 48480.23865882172 is not greater than 48480.254827336736. Delta is -0.01616851501603378
# Model is not converging.  Current: 47799.803774732536 is not greater than 47799.803779071175. Delta is -4.3386389734223485e-06
# Model is not converging.  Current: 47663.972099149025 is not greater than 47663.97818787913. Delta is -0.006088730107876472
# Model is not converging.  Current: 47061.47156654078 is not greater than 47061.48147582351. Delta is -0.009909282729495317
# Model is not converging.  Current: 48205.25636027569 is not greater than 48205.28130206903. Delta is -0.024941793337347917
# Model is not converging.  Current: 49232.00695618548 is not greater than 49232.01245540066. Delta is -0.005499215178133454
# Model is not converging.  Current: 46897.251244435676 is not greater than 46897.2518684868. Delta is -0.0006240511211217381
# Model is not converging.  Current: 47857.949134810384 is not greater than 47857.950943903306. Delta is -0.0018090929224854335
# Model is not converging.  Current: 49801.05364262757 is not greater than 49801.05437125139. Delta is -0.0007286238178494386
# Model is not converging.  Current: 48850.893073582796 is not greater than 49216.48510673247. Delta is -365.59203314967453
# Model is not converging.  Current: 48689.17744395549 is not greater than 48689.179254237715. Delta is -0.001810282228689175
# Model is not converging.  Current: 49940.09854944242 is not greater than 49940.1045966631. Delta is -0.006047220682376064
# Model is not converging.  Current: 49512.6918030421 is not greater than 49512.7109938735. Delta is -0.019190831400919706
# Model is not converging.  Current: 50573.245175832184 is not greater than 50573.26124031431. Delta is -0.016064482122601476
# Model is not converging.  Current: 46653.97614954229 is not greater than 46653.988922225035. Delta is -0.012772682741342578
# Model is not converging.  Current: 49162.38006936439 is not greater than 49162.391898715105. Delta is -0.01182935071119573
# Model is not converging.  Current: 50323.08187852603 is not greater than 50323.08277021274. Delta is -0.0008916867154766805
# ['../../models/Vi/hmm_model_3box_Lou.pkl']

# %%
# Pickle the trained model
with open('../../models/EM/hmm_model_3box_Lou.pkl', 'wb') as file:
    pickle.dump(em_model, file)

# %%
print(em_model.means_)
print(len(em_Z)/30)
print(vi_model.means_)
#print(model.covars_)

# %%
em_states = pd.unique(em_Z)
state_names = ['Relax', 'Observation', 'Fuite', 'Reminiscence']

plt.subplot(2,2,1)
for i in em_states:
    #print(len(X))
    x = np.linspace(1,len(X),len(X))[(em_Z == i)]
    y = X[0:,0][(em_Z == i)]
    plt.plot(x, y, '.')
    plt.title("Left")
plt.subplot(2,2,2)
for i in em_states:
    #print(len(X[1:,0]))
    x = np.linspace(1,len(X),len(X))[(em_Z == i)]
    y = X[0:,1][(em_Z == i)]
    plt.plot(x, y, '.')
    plt.title("Top")
plt.subplot(2,2,3)
for i in em_states:
    x = np.linspace(1,len(X),len(X))[(em_Z == i)]
    y = X[0:,2][(em_Z == i)]
    plt.plot(x, y, '.')
    plt.title("Width")
plt.subplot(2,2,4)
for i in em_states:
    x = np.linspace(1,len(X),len(X))[(em_Z == i)]
    y = X[0:,3][(em_Z == i)]
    plt.plot(x, y, '.')
    plt.title("Height")

plt.tight_layout()
plt.legend(labels=state_names, loc="upper right", ncol=1)
plt.suptitle('Snout and Head and cow Coordinates EM')
# rajouter les etiquettes

# %%
vi_states = pd.unique(vi_Z)

plt.subplot(2,2,1)
for i in vi_states:
    #print(len(X))
    x = np.linspace(1,len(X),len(X))[(vi_Z == i)]
    y = X[0:,0][(vi_Z == i)]
    plt.plot(x, y, '.')
    plt.title('Left')
plt.subplot(2,2,2)
for i in vi_states:
    #print(len(X[1:,0]))
    x = np.linspace(1,len(X),len(X))[(vi_Z == i)]
    y = X[0:,1][(vi_Z == i)]
    plt.plot(x, y, '.')
    plt.title('Top')
plt.subplot(2,2,3)
for i in vi_states:
    x = np.linspace(1,len(X),len(X))[(vi_Z == i)]
    y = X[0:,2][(vi_Z == i)]
    plt.plot(x, y, '.')
    plt.title('Width')
plt.subplot(2,2,4)
for i in vi_states:
    x = np.linspace(1,len(X),len(X))[(vi_Z == i)]
    y = X[0:,3][(vi_Z == i)]
    plt.plot(x, y, '.')
    plt.title('Height')

plt.tight_layout()
plt.legend(labels=state_names, loc="upper right", ncol=1)
plt.suptitle('Snout and Head and cow Coordinates VI')

# %%
transition_matrix = em_model.transmat_
plt.figure(figsize=(5, 4))
sns.heatmap(transition_matrix, annot=True, cmap="YlGnBu", cbar=False)
plt.title('State Transition Probabilities')
plt.xlabel('To State')
plt.ylabel('From State')
plt.show()

# %%
transition_matrix = vi_model.transmat_
plt.figure(figsize=(7, 6))
sns.heatmap(transition_matrix, annot=True, cmap="YlGnBu", cbar=False)
plt.title('State Transition Probabilities for all three boxes')
plt.xlabel('To State')
plt.ylabel('From State')
plt.show()

# %%
""" predicted_state = em_model.predict_proba(X)
predicted_state
df = pd.DataFrame(predicted_state)
df.to_csv("../INF889E Project/Trained data/EM/predict_3boxes.csv")

 """

# %%
""" 

df = pd.DataFrame({'original_state': em_Z})
df.to_csv("../INF889E Project/Trained data/EM/head_Snout_cow_coords_hmmstates.csv")
df=pd.DataFrame({'states':vi_Z})
df.to_csv("../INF889E Project/Trained data/VI/head_Snout_cow_coords_hmmstates.csv") """

# %%
# Create a directed graph using NetworkX
G = nx.DiGraph()
transition_matrix = em_model.transmat_
num_states = transition_matrix.shape[0]
dic_state = {
    1 : 'Resting',
    3 : 'Observing',
    2 : 'Flight',
    0 : 'Reminiscing'
}
for i in range(num_states):
    for j in range(num_states):
        prob = transition_matrix[i, j]
        if prob > 0:  # Only add edges for non-zero probabilities
            G.add_edge(f' {dic_state[i]}', f' {dic_state[j]}', weight=prob)


# Use a color palette from seaborn for visual appeal
colors = sns.color_palette("pastel", num_states)

# Visualize the graph with enhanced aesthetics
pos = nx.circular_layout(G)
edge_labels = {(n1, n2): f"{d['weight']:.5f}" for n1, n2, d in G.edges(data=True)}

plt.figure(figsize=(7, 7))
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color=colors, node_shape="o", alpha=0.7)
nx.draw_networkx_edges(G, pos, width=2, edge_color="gray", arrowsize=20)
nx.draw_networkx_labels(G, pos, font_size=8, font_weight='bold')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red', font_size=12)

plt.title('Hidden Markov Model Transition States -EM-', fontsize=18)
plt.axis('off')
plt.show()

# %%
# Create a directed graph using NetworkX
G = nx.DiGraph()
transition_matrix = vi_model.transmat_
num_states = transition_matrix.shape[0]
for i in range(num_states):
    for j in range(num_states):
        prob = transition_matrix[i, j]
        if prob > 0:  # Only add edges for non-zero probabilities
            G.add_edge(dic_state[i], dic_state[j], weight=prob)

# Use a color palette from seaborn for visual appeal
colors = sns.color_palette("pastel", num_states)

# Visualize the graph with enhanced aesthetics
pos = nx.circular_layout(G)
edge_labels = {(n1, n2): f"{d['weight']:.5f}" for n1, n2, d in G.edges(data=True)}

plt.figure(figsize=(7, 7))
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color=colors, node_shape="o", alpha=0.7)
nx.draw_networkx_edges(G, pos, width=2, edge_color="gray", arrowsize=20)
nx.draw_networkx_labels(G, pos, font_size=8, font_weight='bold')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red', font_size=12)

plt.title('Hidden Markov Model Transition States -VI-', fontsize=18)
plt.axis('off')
plt.show()
